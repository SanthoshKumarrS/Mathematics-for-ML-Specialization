# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Week 1 : Introduction to Probability & Probability Distributions :</span>

# %% [markdown]
# `Intro to Probabilty`
#
# - numerator = **Event**
# - Denominator = **Sample Space**
# - Denoted as P(Event)
#
# ✔️ Probabilty = Event / Sample Space
#
# `Complement of Probability`
#
# - Comlement rule = 1 - Probility of Event Occuring **P(A') = 1 - P(A)**
#
# `Sum of Probabilities (DisJoined events)`
#
# P (A U B) = P(A) + P(B) ( Mutually Exclusive)
#
# - Two events of same sampe size can be added to get the sum of probabilities
#
# `joint events`
#
# P ( A U B ) = P(A) + P(B) - P( A ∩ B ) --> (Non MutuallyExclusive)
#
# - Intersection is both events occuring on the sample sample
#
# `Independence`
#
# In probability theory, two events are considered independent if the occurrence of one event does not affect the probability of the other event occurring.
#
# - Mathematically, events A and B are independent if:
#
# P( A ∩ B ) = P(A) ⋅ P(B)
#
# `Conditional Probabilty`
#
# Conditional probability is the probability of an event occurring given that another event has already occurred. It's denoted as
# P(A∣B), where A and B are two events.
#
# - The formula for conditional probability is:
#
# P(A ∣ B)= P(B) / P(A ∩ B)
#
# `Bayes Theorem :`
#
# Bayes' theorem is a fundamental concept in probability theory that allows us to update our beliefs about the probability of an event occurring based on new evidence or information. It relates the conditional probability of two events in terms of each other.
#
# - Bayes' theorem is formulated as:
#
# P(A∣B)= P(B∣A) * P(A) / P(B)
#
#
# ### <span style="font-family:cursive;text-align:center"> Probability Distributions :</span>
#
# `Random Variables`
#
# `X` can be a random variable with uncertain outcomes & not deterministic
#
# - Discrete random variables = When it's a list (can take only a countable no of values)
# - Continuous random variables - Infinte no of values (takes values at at an interval)
#
# `Normal Distribution`
#
# - `u` is the mean
# - `standard deviation` is the breadth

# %% [markdown]
# # <span style="font-family:cursive;text-align:center">Week 2 : Describing Probability Distributions & Probability Distributions with Multiple variables :</span>

# %% [markdown]
# `Mean, Median & Mode`
#
# - The point where the continous distribution curve is balanced is the `Mean` = mu .
# - Outliers may affect the mean of the distribution
# - `Median` is the middle number of a distribution
# - `Mode` the value at ehich the distribution has the highest probability (heighest hegiht in continous distribution)
# - When there are many peaks it's known as MultiNodal Distribution
# - For a normal distibution Mean,Median and Mode are all same
#
# `Expected Value`
#
# - The expected value of a random variable is the average of all possible outcomes, weighted by their probabilities.
# - Expected value of a sum of n variables is the sum of their expected values
#
# `Variance`
#
# Variance is a measure of how spread out the values of a random variable are from the expected value. It is calculated by taking the average of the squared deviations from the expected value.
#
# `Standard Deviation `
#
# - Standard deviation is a measure of how spread out the values of a random variable are from the expected value. It is calculated by taking the square root of the variance.
#
# - The standard deviation of a random variable X is denoted by σ(X) and is calculated as follows:
#
# σ(X) = √Var(X)
# where:
#
# * σ(X) is the standard deviation of X
# * Var(X) is the variance of X
#
# `Standardizing the Equation`
#
# To standardize a distribution, you subtract the mean from each value and then divide by the standard deviation. This process is also known as z-scoring.
#
# - The following formula is used to standardize a distribution:
#
# z = (x - μ) / σ
# where:
#
# * z is the standardized value
# * x is the original value
# * μ is the mean of the distribution
# * σ is the standard deviation of the distribution
#
# `Skewness`
#
# When expected,value & variance can't show the skewness ,Take power of 3
#
# - Positively skewed = Tail on the right and greater than 0
# - Not Skewed = Looks Symmetric and = 0
# - Negatively skewed = Tail on the left and less than 0
#
# When all the 3 moments did'nt work Power can be raised to 4 and this is called Kurtosis
# - Tail will be long and thick,Since the values at end might be higher
#
# `Box-Plots`
#
# What can you tell from it ?
#
# * If the data is skewed,
# * Check for Outliers
# * Analyze dispersion
#
# `Kernel density Estimation`
#
# Kernel density estimation (KDE) is a non-parametric method for estimating the probability density function of a random variable. It does this by using a kernel function to weight the data points in a dataset.
#
# `Violin Plots`
#
# - Violin plots is KDE put on side of box plots with Q1,Q3,Median,Whiskers,etc.. of Box plot
# - They are used to visualize the distribution of a numerical variable across one or more categories.
#
# `QQ Plots`
#
# - Sometimes Normal distribution can be found with histogram,But in peckuliar cases Quantile-Quantile plots (QQ Plots) are used to compare Quantiles
# - If the data is normaly distributed ,Scatter quantile points will mostly align with the X line
#
# `joint Distributions`
#
# - When variables are independent probability = p(X) * P(y)
#
# `Co-variance` (correlation)
#
# - x and Y values are subtracted by Mean and the product of them is Summed up and divided by `n` to obtain the covariance
#
# `Correlation Co-efficient`
#
# The correlation coefficient is a statistical measure of the strength and direction of the relationship between two variables. It is a dimensionless number that can range from -1 to 1. A correlation coefficient of -1 indicates a perfect negative relationship, a correlation coefficient of 0 indicates no relationship, and a correlation coefficient of 1 indicates a perfect positive relationship.
#
# - The correlation coefficient is calculated using the following formula:
#
# correlation_coefficient = (Σ(x - μ_x)(y - μ_y)) / (n * σ_x * σ_y)
# where:
#
# * x is a value in the first variable
# * y is a value in the second variable
# * μ_x is the mean of the first variable
# * μ_y is the mean of the second variable
# * σ_x is the standard deviation of the first variable
# * σ_y is the standard deviation of the second variable
# * n is the number of observations
#
# `Multivariate Gaussian Distribution`
#
# - Independent distribution is more symmetric than independent ones
# - Informal shape in dependent variables is due to the co-variance
